# %% [markdown]
# # Python 심화

# %% [markdown]
# ## 문제: 클래스 상속
# 01.2코드에서 `Point` 클래스를 구현하는 방법을 공부했습니다. 또한 Point 인스턴스를 멤버 변수로 가지는 `Circle` 클래스를 구현했습니다.
# - 목표: __Point 클래스를 상속하는 Circle 클래스를 구현합니다.__
# > 1. 점과 원 사이의 거리를 계산할 수 있도록 `distance` 함수를 상속/재정의해야 합니다.
# > 2. `Circle` 클래스의 `distance` 함수는 원의 중심과 주어진 점 / 주어진 원의 중심 사이의 거리를 계산해야 합니다.
# > 3._x, y 멤버 변수는 Circle 클래스에서 원의 중심 위치가 됩니다._

# %%
# Write your own code!

# %% [markdown]
# ---

# %%
p = Point(0, 0)
c = Circle((5, 0), 3)
print(p.distance(c))
print(c.distance(p))
